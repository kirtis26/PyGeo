# %% [markdown]
# GPX (англ. GPS eXchange Format) — свободный текстовый формат хранения и обмена данными GPS, основанный на XML.
#
# Формат позволяет хранить информацию об ориентирах (waypoints), маршрутах (routes) и треках (tracklogs). Для каждой точки хранятся её долгота, широта и высота над уровнем моря (если имеется информация о высоте). Для точек трека хранится также время прохождения точки. XML-схема предусматривает также хранение произвольной пользовательской информации по каждой точке, обязательными являются только долгота и широта. Широта и долгота в GPX указывается в градусах в системе координат WGS 84. Высота указывается в метрах над уровнем моря. Для времени используется стандарт UTC в формате ISO 8601. Примером пользовательской информации может быть высота местности (ele), скорость, частота пульса (hr), число шагов, темп вращения педалей (каденс, cad), температура и им подобные параметры.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://ru.wikipedia.org/wiki/GPX

# %% [markdown]
# Точка (waypoint) обозначается тегом <wpt> и означает отдельную путевую точку, которая по сути является маркером. Её координаты задаются атрибутами lat и lon, высота может задаваться необязательным тегом <ele>. Точка может содержать и другие теги, например <name>.
#
# Список маршрутов обозначается тегом <rte> — упорядоченный список путевых точек, представляющих ряд точек поворота, ведущих к месту назначения. Кроме собственно точек поворота <rtept> может включать имя, описание, комментарий, ссылки и свои собственные элементы из другой схемы.
#
# Трек (Track) — последовательность точек с отметками времени их прохождения, обозначаемая тегом <trk>. Содержит в себе элементы <trkseg> (отрезки трека), которые в свою очередь состоят из точек, задаваемых тегом <trkpt>. Координаты точек трека задаются аналогично координатам для waypoint.

# %%
file_name = 'ATB-Heerenveen.gpx'
# file_name = '-  ( Timur).gpx' # вот это говняный файл
# file_name = '- -  -  -.gpx' # вот это говняный файл
file_name = 'track37.gpx'
# file_name = '2d8a243760.gpx'
# file_name = '2d2e265529.gpx'
# file_name = '516e261279.gpx'

# %%
file_name = '267_track.gpx'

# %%
# функция open() возвращает объект file и чаще всего используется с двумя аргументами: open(имя файла, режим).
gpx_file = open(file_name, 'r', encoding="utf-8")

# %%
# gpx_file.read()

# %%
# gpx_file.readline() читает каждую строку (строки разделены \n) в файле и выбрасывает ее из gpx_file

# %%
# gpx_file.readlines() читает файл и возвращает все строки в нем и выбрасывает из gpx_file

# %%
for line in gpx_file:
    print(line, end='')
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?>
# <gpx version="1.1" creator="Locus Map, Android"
#  xmlns="http://www.topografix.com/GPX/1/1"
#  xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#  xsi:schemaLocation="http://www.topografix.com/GPX/1/1 http://www.topografix.com/GPX/1/1/gpx.xsd"
#  xmlns:gpxx="http://www.garmin.com/xmlschemas/GpxExtensions/v3"
#  xmlns:gpxtrkx="http://www.garmin.com/xmlschemas/TrackStatsExtension/v1"
#  xmlns:gpxtpx="http://www.garmin.com/xmlschemas/TrackPointExtension/v2"
#  xmlns:locus="http://www.locusmap.eu">
# 	<metadata>
# 		<desc>File with points/tracks from Locus Map/3.49.0</desc>
# 	</metadata>
# <trk>
# <name>2020-10-25 11:50:10</name>
# 	<extensions>
# 		<line xmlns="http://www.topografix.com/GPX/gpx_style/0/2">
# 			<color>0000FF</color>
# 			<opacity>0.59</opacity>
# 			<width>6.0</width>
# 			<extensions>
# 				<locus:lsColorBase>#960000FF</locus:lsColorBase>
# 				<locus:lsWidth>6.0</locus:lsWidth>
# ...

# %%
list_lines = gpx_file.readlines()

# %%
list_lines
# Out:
# ['<?xml version="1.0" encoding="UTF-8"?>\n',
#  '<gpx xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.topografix.com/GPX/1/0" xsi:schemaLocation="http://www.topografix.com/GPX/1/0 http://www.topografix.com/GPX/1/0/gpx.xsd" version="1.0" creator="GPSMapEdit 2.1.78.9 - http://www.geopainting.com">\n',
#  '<time>2017-10-03T18:42:09Z</time>\n',
#  '<bounds minlat="54.867779" maxlat="54.988046" minlon="38.031015" maxlon="38.217723"></bounds>\n',
#  '<wpt lat="54.869992" lon="38.14599">\n',
#  '<name>BELOPES</name></wpt>\n',
#  '<wpt lat="54.870721" lon="38.152851">\n',
#  '<name>X01</name></wpt>\n',
#  '<wpt lat="54.869619" lon="38.154579">\n',
#  '<name>X02</name></wpt>\n',
#  '<wpt lat="54.869532" lon="38.155727">\n',
#  '<name>X03</name></wpt>\n',
#  '<wpt lat="54.868986" lon="38.156918">\n',
#  '<name>X04</name></wpt>\n',
#  '<wpt lat="54.868544" lon="38.157213">\n',
#  '<name>X05</name></wpt>\n',
#  '<wpt lat="54.869436" lon="38.171101">\n',
# ...

# %%
list_index = []
for index_line in range(len(list_lines)):
    if list_lines[index_line].find('<trk>') != -1:
        list_index.append(index_line+1)

# %%
print(list_index)
# list_index - список индексов строк в исходном файле, где содержаться названия треков
# Таким образом длина этого списка (количество элементов в нем) это количество треков в файле
# Out:
# [13]

# %%
for i in list_index:
    print(list_lines[i])
# Out:
# <name>2020-10-25 11:50:10</name>

# %%
list_lines[13]
# Out:
# '<name>2020-10-25 11:50:10</name>\n'

# %%
len(list_lines[13])
# Out:
# 33

# %%
list_lines[13][6:]
# Out:
# '2020-10-25 11:50:10</name>\n'

# %%
list_lines[13][6:-8]
# Out:
# '2020-10-25 11:50:10'

# %%
name_tracks = []
for i in list_index:
    ind_name_begin = list_lines[i].find('<name>') + 6
    ind_name_end = list_lines[i].rfind('</name>')
    name_tracks.append(list_lines[i][ind_name_begin:ind_name_end])

# %%
print(name_tracks)
# Out:
# ['2020-10-25 11:50:10']

# %%
# собираем точки и отрезки

# %%
tracks = []

for index_line in range(len(list_lines)):
    
    if list_lines[index_line].find('<trk>') != -1:
        
        track = []
        flag_trk = True
        i = index_line
        while flag_trk == True:
            
            flag_seg = False
            while flag_seg == False:
                if list_lines[i].find('<trkseg>') != -1:
                    flag_seg = True
                else:
                    i += 1
        
            segment = []
            while flag_seg == True:
                if list_lines[i].find('<trkpt') != -1:
                    lat_begin = list_lines[i].find('lat="') + 5
                    lat_end = list_lines[i].find('"', lat_begin)
                    lat = float(list_lines[i][lat_begin:lat_end])
                    lon_begin = list_lines[i].find('lon="') + 5
                    lon_end = list_lines[i].find('"', lon_begin)
                    lon = float(list_lines[i][lon_begin:lon_end])
                    point = {'lat': lat,
                             'lon': lon}
                    segment.append(point)
                    i += 1
                elif list_lines[i].find('</trkseg>') != -1:
                    flag_seg = False
                else:
                    i += 1
        
            track.append(segment)
            
            i += 1
            if list_lines[i].find('</trk>') != -1:
                flag_trk = False
        tracks.append(track)

# %%
len(tracks)
# Out:
# 1

# %%
len(tracks[0])
# Out:
# 2

# %%
len(tracks[0][1])
# Out:
# 388

# %%
tracks[0][1][0]
# Out:
# {'lat': 61.9110515, 'lon': 34.4557096}

# %%
tracks[0][1][1]
# Out:
# {'lat': 61.9110533, 'lon': 34.4557342}

# %%
import numpy as np

# %%
def distance(point_1, point_2):
    """
    Формула Хаверсина для расчета дистанции между двумя точками соседними
    """
    r = 6371302
    phi1 = point_1['lat'] * np.pi/180
    phi2 = point_2['lat'] * np.pi/180
    lam1 = point_1['lon'] * np.pi/180
    lam2 = point_2['lon'] * np.pi/180
    return 2 * r * np.arcsin(np.sqrt(np.sin((phi2 - phi1)/2)**2 + np.cos(phi1)*np.cos(phi2)*np.sin((lam2-lam1)/2)**2))

# %%
distance(tracks[0][1][0], tracks[0][1][1])
# Out:
# 1.303459285965882

# %%
for i in range(len(tracks)):
    dist_track = 0
    for j in range(len(tracks[i])):
        for k in range(len(tracks[i][j])-1):
            dist_track += distance(tracks[i][j][k], tracks[i][j][k+1])
    print(f'Distance track №{i+1}: {dist_track} м')
# Out:
# Distance track №1: 6040.078456323074 м

# %% [markdown]
# # Обработчик файлов с помощью одной функции

# %% [markdown]
# **Ты передаешь в функцию name_track название файла и на выходе этой функции мы получаем количество треков в файле и их названия. Если файл попадается говняный (бывает такое) и в нем нет названия трека после строки "< trk>", то выводится "Name tracks is not fined"**

# %%
import numpy as np

# %%
def name_track(file_name):
    
    gpx_file = open(file_name, 'r', encoding="utf-8")
    list_lines = gpx_file.readlines()
    
    k = 0
    list_index = []
    for index_line in range(len(list_lines)):
        if list_lines[index_line].find('<trk>') != -1:
            k += 1
            if list_lines[index_line+1].find('<name>') != -1:
                list_index.append(index_line+1)
    
    print(f'Count tracks: {k}')
    
    name_tracks = []
    
    if len(list_index) != 0:
        for i in list_index:
            ind_name_begin = list_lines[i].find('<name>') + 6
            ind_name_end = list_lines[i].rfind('</name>')
            name_tracks.append(list_lines[i][ind_name_begin:ind_name_end])
        return name_tracks
    
    else:
        print('Name tracks is not fined in trk: error structure file .gpx')
        return name_tracks

# %%
def distance(point_1, point_2):
    """
    Формула Хаверсина для расчета дистанции между двумя точками соседними
    """
    r = 6371302
    phi1 = point_1['lat'] * np.pi/180
    phi2 = point_2['lat'] * np.pi/180
    lam1 = point_1['lon'] * np.pi/180
    lam2 = point_2['lon'] * np.pi/180
    return 2 * r * np.arcsin(np.sqrt(np.sin((phi2 - phi1)/2)**2 + np.cos(phi1)*np.cos(phi2)*np.sin((lam2-lam1)/2)**2))

# %%
tracks = []

for index_line in range(len(list_lines)):
    
    if list_lines[index_line].find('<trk>') != -1:
        
        track = []
        flag_trk = True
        i = index_line
        while flag_trk == True:
            
            flag_seg = False
            while flag_seg == False:
                if list_lines[i].find('<trkseg>') != -1:
                    flag_seg = True
                else:
                    i += 1
        
            segment = []
            while flag_seg == True:
                if list_lines[i].find('<trkpt') != -1:
                    lat_begin = list_lines[i].find('lat="') + 5
                    lat_end = list_lines[i].find('"', lat_begin)
                    lat = float(list_lines[i][lat_begin:lat_end])
                    lon_begin = list_lines[i].find('lon="') + 5
                    lon_end = list_lines[i].find('"', lon_begin)
                    lon = float(list_lines[i][lon_begin:lon_end])
                    point = {'lat': lat,
                             'lon': lon}
                    segment.append(point)
                    i += 1
                elif list_lines[i].find('</trkseg>') != -1:
                    flag_seg = False
                else:
                    i += 1
        
            track.append(segment)
            
            i += 1
            if list_lines[i].find('</trk>') != -1:
                flag_trk = False
        tracks.append(track)

# %%
for i in range(len(tracks)):
    dist_track = 0
    for j in range(len(tracks[i])):
        for k in range(len(tracks[i][j])-1):
            dist_track += distance(tracks[i][j][k], tracks[i][j][k+1])
    print(f'Distance track №{i+1}: {dist_track} м')

# %%
# file_name = 'ATB-Heerenveen.gpx'
# file_name = '-  ( Timur).gpx' # вот это говняный файл
# file_name = '- -  -  -.gpx' # вот это говняный файл
# file_name = 'track37.gpx'
# file_name = '2d8a243760.gpx'
# file_name = '2d2e265529.gpx'
# file_name = '516e261279.gpx'

# %%
print(name_track(file_name))
# Out:
# Count tracks: 2
# ['Белопесоцкий — Возрождение', 'Возрождение — Жилево']

# %% [markdown]
# # ДОПОЛНИТЕЛЬНО

# %% [markdown]
# # 1)

# %% [markdown]
# pip install tkinter

# %%
import tkinter

# %%
tkinter.filedialog
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-dc69731909f9> in <module>
# ----> 1 tkinter.filedialog
#
# AttributeError: module 'tkinter' has no attribute 'filedialog'

# %% [markdown]
# # 3)

# %%
import os
import random

# %%
DIR = 'gpx'

# %%
file_name = 'ATB-Heerenveen.gpx'

# %%
# gpx_file = open(os.path.join(DIR, random.choice(os.listdir(DIR))))
gpx_file = open(file_name, 'r', encoding="utf-8")

# %%
list_lines = gpx_file.readlines()

# %%
wpts = []

# %%
for index_line in range(len(list_lines)):
    
    if list_lines[index_line].find('<wpt') != -1:
        
        ind_str_name = index_line
        flag_wpt = True
        
        while flag_wpt == True: 
            
            if list_lines[ind_str_name].find('<name>') != -1:
                ind_name_begin = list_lines[ind_str_name].find('<name>') + 6
                ind_name_end = list_lines[ind_str_name].find('</name>')
                name = list_lines[ind_str_name][ind_name_begin:ind_name_end]
                wpts.append(name)
            if list_lines[ind_str_name].find('</wpt>') != -1:
                flag_wpt = False
            ind_str_name += 1
if len(wpts) == 0:
    print('Wpt is not definded')
else:
    print(wpts)
# Out:
# ['Afslaan doorsteek nog 8km', 'Evt rechtdoor doorsteken', 'Parking-ATB', 'Afslaan doorsteek nog 8km', 'Evt rechtdoor doorsteken', 'Parking-ATB', 'Afslaan doorsteek nog 8km', 'Evt rechtdoor doorsteken', 'Parking-ATB', 'Afslaan doorsteek nog 8km', 'Evt rechtdoor doorsteken', 'Parking-ATB']
